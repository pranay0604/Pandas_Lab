# %%
import numpy as np
import pandas as pd

# %%
ds = pd.Series([12,21,123,32,43,34])
ds
# Out:
# 0     12
# 1     21
# 2    123
# 3     32
# 4     43
# 5     34
# dtype: int64

# %%
ds.shape
# Out:
# (6,)

# %%
ds.dtype
# Out:
# dtype('int64')

# %%
ds.size
# Out:
# 6

# %%
ds.ndim
# Out:
# 1

# %%
ds.nbytes
# Out:
# 48

# %%
ds.item
# Out:
# <bound method IndexOpsMixin.item of 0     12
# 1     21
# 2    123
# 3     32
# 4     43
# 5     34
# dtype: int64>

# %%
ds.items
# Out:
# <bound method Series.items of 0     12
# 1     21
# 2    123
# 3     32
# 4     43
# 5     34
# dtype: int64>

# %%
data = {
    "City": ["New York", "London", "Paris", "Tokyo", "Sydney"],
    "Country": ["USA", "UK", "France", "Japan", "Australia"],
    "Population_Millions": [8.42, 8.98, 2.15, 13.93, 5.31]
}

df = pd.DataFrame(data)

print(df)
# Out:
#        City    Country  Population_Millions
# 0  New York        USA                 8.42
# 1    London         UK                 8.98
# 2     Paris     France                 2.15
# 3     Tokyo      Japan                13.93
# 4    Sydney  Australia                 5.31

# %%
df
# Out:
#        City    Country  Population_Millions
# 0  New York        USA                 8.42
# 1    London         UK                 8.98
# 2     Paris     France                 2.15
# 3     Tokyo      Japan                13.93
# 4    Sydney  Australia                 5.31

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 5 non-null      object
#  1   Country              5 non-null      object
#  2   Population_Millions  5 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 252.0+ bytes

# %%
df.info
# Out:
# <bound method DataFrame.info of        City    Country  Population_Millions
# 0  New York        USA                 8.42
# 1    London         UK                 8.98
# 2     Paris     France                 2.15
# 3     Tokyo      Japan                13.93
# 4    Sydney  Australia                 5.31>

# %%
df.size
# Out:
# 15

# %%
df.loc[5] = ['Tokyo','UK',8.9]

# %%
df
# Out:
#        City    Country  Population_Millions
# 0  New York        USA                 8.42
# 1    London         UK                 8.98
# 2     Paris     France                 2.15
# 3     Tokyo      Japan                13.93
# 4    Sydney  Australia                 5.31
# 5     Tokyo         UK                 8.90

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 6 non-null      object
#  1   Country              6 non-null      object
#  2   Population_Millions  6 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 192.0+ bytes

# %%
df.loc[5] = ['Tokyo','UK',8.9]

# %%
df.loc[6] = ['Tokyo','UK',np.nan]

# %%
df
# Out:
#        City    Country  Population_Millions
# 0  New York        USA                 8.42
# 1    London         UK                 8.98
# 2     Paris     France                 2.15
# 3     Tokyo      Japan                13.93
# 4    Sydney  Australia                 5.31
# 5     Tokyo         UK                 8.90
# 6     Tokyo         UK                  NaN

# %%
df.isna() # returns True if value is null
# Out:
#     City  Country  Population_Millions
# 0  False    False                False
# 1  False    False                False
# 2  False    False                False
# 3  False    False                False
# 4  False    False                False
# 5  False    False                False
# 6  False    False                 True

# %%
df[df.isna()]
# Out:
#   City Country  Population_Millions
# 0  NaN     NaN                  NaN
# 1  NaN     NaN                  NaN
# 2  NaN     NaN                  NaN
# 3  NaN     NaN                  NaN
# 4  NaN     NaN                  NaN
# 5  NaN     NaN                  NaN
# 6  NaN     NaN                  NaN

# %%
df
# Out:
#        City    Country  Population_Millions
# 0  New York        USA                 8.42
# 1    London         UK                 8.98
# 2     Paris     France                 2.15
# 3     Tokyo      Japan                13.93
# 4    Sydney  Australia                 5.31
# 5     Tokyo         UK                 8.90
# 6     Tokyo         UK                  NaN

# %%
df.notna() # return True if those are not null
# Out:
#    City  Country  Population_Millions
# 0  True     True                 True
# 1  True     True                 True
# 2  True     True                 True
# 3  True     True                 True
# 4  True     True                 True
# 5  True     True                 True
# 6  True     True                False

# %%
df[df.notna()]
# Out:
#        City    Country  Population_Millions
# 0  New York        USA                 8.42
# 1    London         UK                 8.98
# 2     Paris     France                 2.15
# 3     Tokyo      Japan                13.93
# 4    Sydney  Australia                 5.31
# 5     Tokyo         UK                 8.90
# 6     Tokyo         UK                  NaN

# %%
df.describe()
# Out:
#        Population_Millions
# count             6.000000
# mean              7.948333
# std               3.963692
# min               2.150000
# 25%               6.087500
# 50%               8.660000
# 75%               8.960000
# max              13.930000

# %%
df.dropna() # remove null values rows in dataset
# Out:
#        City    Country  Population_Millions
# 0  New York        USA                 8.42
# 1    London         UK                 8.98
# 2     Paris     France                 2.15
# 3     Tokyo      Japan                13.93
# 4    Sydney  Australia                 5.31
# 5     Tokyo         UK                 8.90

# %%
df.loc[5,'Country']='Japan'
df.dropna()
# Out:
#        City    Country  Population_Millions
# 0  New York        USA                 8.42
# 1    London         UK                 8.98
# 2     Paris     France                 2.15
# 3     Tokyo      Japan                13.93
# 4    Sydney  Australia                 5.31
# 5     Tokyo      Japan                 8.90

# %%
import pandas as pd
import numpy as np

data = {
    "City": ["Berlin", np.nan, "Rome", np.nan, "Toronto"],
    "Country": [np.nan, "Spain", "Italy", np.nan, "Canada"],
    "Population_Millions": [3.6, np.nan, 2.8, 9.7, np.nan]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       City Country  Population_Millions
# 0   Berlin     NaN                  3.6
# 1      NaN   Spain                  NaN
# 2     Rome   Italy                  2.8
# 3      NaN     NaN                  9.7
# 4  Toronto  Canada                  NaN

# %%
df
# Out:
#       City Country  Population_Millions
# 0   Berlin     NaN                  3.6
# 1      NaN   Spain                  NaN
# 2     Rome   Italy                  2.8
# 3      NaN     NaN                  9.7
# 4  Toronto  Canada                  NaN

# %%
df.dropna(subset=['City'])
# Out:
#       City Country  Population_Millions
# 0   Berlin     NaN                  3.6
# 2     Rome   Italy                  2.8
# 4  Toronto  Canada                  NaN

# %%
df.dropna(subset=['Country'])
# Out:
#       City Country  Population_Millions
# 1      NaN   Spain                  NaN
# 2     Rome   Italy                  2.8
# 4  Toronto  Canada                  NaN

# %%
df.dropna(subset=['Population_Millions'])
# Out:
#      City Country  Population_Millions
# 0  Berlin     NaN                  3.6
# 2    Rome   Italy                  2.8
# 3     NaN     NaN                  9.7

# %%
df.dropna(subset=['City','Country','Population_Millions'])
# Out:
#    City Country  Population_Millions
# 2  Rome   Italy                  2.8

# %%
df
# Out:
#       City Country  Population_Millions
# 0   Berlin     NaN                  3.6
# 1      NaN   Spain                  NaN
# 2     Rome   Italy                  2.8
# 3      NaN     NaN                  9.7
# 4  Toronto  Canada                  NaN

# %%
df.dropna(subset=['City'],how='any',axis=0)
# Out:
#       City Country  Population_Millions
# 0   Berlin     NaN                  3.6
# 2     Rome   Italy                  2.8
# 4  Toronto  Canada                  NaN

# %%
df.dropna(subset=['Country'], how='any', axis=0)
# Out:
#       City Country  Population_Millions
# 1      NaN   Spain                  NaN
# 2     Rome   Italy                  2.8
# 4  Toronto  Canada                  NaN

# %%
df.dropna(subset=['Population_Millions'], how='any', axis=0)
# Out:
#      City Country  Population_Millions
# 0  Berlin     NaN                  3.6
# 2    Rome   Italy                  2.8
# 3     NaN     NaN                  9.7

# %%
df.dropna(how='any',axis=0)
# Out:
#    City Country  Population_Millions
# 2  Rome   Italy                  2.8

# %%
df.dropna(how='all',axis=1)
# Out:
#       City Country  Population_Millions
# 0   Berlin     NaN                  3.6
# 1      NaN   Spain                  NaN
# 2     Rome   Italy                  2.8
# 3      NaN     NaN                  9.7
# 4  Toronto  Canada                  NaN

# %%
df.dropna(how='any',axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df
# Out:
#       City Country  Population_Millions
# 0   Berlin     NaN                  3.6
# 1      NaN   Spain                  NaN
# 2     Rome   Italy                  2.8
# 3      NaN     NaN                  9.7
# 4  Toronto  Canada                  NaN

# %%
df.dropna(subset=['Population_Millions'])
# Out:
#      City Country  Population_Millions
# 0  Berlin     NaN                  3.6
# 2    Rome   Italy                  2.8
# 3     NaN     NaN                  9.7

# %%
df.duplicated() # return duplicate rows or records
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
data = pd.Series(['python','c','python','java','python','java'])

data
# Out:
# 0    python
# 1         c
# 2    python
# 3      java
# 4    python
# 5      java
# dtype: object

# %%
data.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0    python
# 1         c
# 2    python
# 3      java
# 4    python
# 5      java
# dtype: object>

# %%
data.value_counts() # return counts of duplicates
# Out:
# python    3
# java      2
# c         1
# Name: count, dtype: int64

# %%
data.value_counts(ascending=True)
# Out:
# c         1
# java      2
# python    3
# Name: count, dtype: int64

# %%
data.value_counts(normalize=True)
# Out:
# python    0.500000
# java      0.333333
# c         0.166667
# Name: proportion, dtype: float64

# %%
df['Population_Millions'].astype('float')
# Out:
# 0    3.6
# 1    NaN
# 2    2.8
# 3    9.7
# 4    NaN
# Name: Population_Millions, dtype: float64

# %%
data
# Out:
# 0    python
# 1         c
# 2    python
# 3      java
# 4    python
# 5      java
# dtype: object

# %%
df
# Out:
#       City Country  Population_Millions
# 0   Berlin     NaN                  3.6
# 1      NaN   Spain                  NaN
# 2     Rome   Italy                  2.8
# 3      NaN     NaN                  9.7
# 4  Toronto  Canada                  NaN

# %%
df.loc[1,'Population_Millions']=2.9

# %%
df
# Out:
#       City Country  Population_Millions
# 0   Berlin     NaN                  3.6
# 1      NaN   Spain                  2.9
# 2     Rome   Italy                  2.8
# 3      NaN     NaN                  9.7
# 4  Toronto  Canada                  NaN

# %%
df.loc[4,'Population_Millions']=4.9

# %%
df
# Out:
#       City Country  Population_Millions
# 0   Berlin     NaN                  3.6
# 1      NaN   Spain                  2.9
# 2     Rome   Italy                  2.8
# 3      NaN     NaN                  9.7
# 4  Toronto  Canada                  4.9

# %%
df['Population_Millions'] > 5
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Population_Millions, dtype: bool

# %%
df[df['Population_Millions'] > 5]
# Out:
#   City Country  Population_Millions
# 3  NaN     NaN                  9.7

# %%
df[df['Population_Millions'] < 5]
# Out:
#       City Country  Population_Millions
# 0   Berlin     NaN                  3.6
# 1      NaN   Spain                  2.9
# 2     Rome   Italy                  2.8
# 4  Toronto  Canada                  4.9

# %%
df.set_index('City',inplace=True)

# %%
df
# Out:
#         Country  Population_Millions
# City
# Berlin      NaN                  3.6
# NaN       Spain                  2.9
# Rome      Italy                  2.8
# NaN         NaN                  9.7
# Toronto  Canada                  4.9

# %%
df.reset_index()
# Out:
#       City Country  Population_Millions
# 0   Berlin     NaN                  3.6
# 1      NaN   Spain                  2.9
# 2     Rome   Italy                  2.8
# 3      NaN     NaN                  9.7
# 4  Toronto  Canada                  4.9

# %%
df
# Out:
#         Country  Population_Millions
# City
# Berlin      NaN                  3.6
# NaN       Spain                  2.9
# Rome      Italy                  2.8
# NaN         NaN                  9.7
# Toronto  Canada                  4.9

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       City Country  Population_Millions
# 0   Berlin     NaN                  3.6
# 1      NaN   Spain                  2.9
# 2     Rome   Italy                  2.8
# 3      NaN     NaN                  9.7
# 4  Toronto  Canada                  4.9

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [5, 13, 22, 55, 49]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age
# 0    Alice    5
# 1      Bob   13
# 2  Charlie   22
# 3    David   55
# 4      Eva   49

# %%
df
# Out:
#       Name  Age
# 0    Alice    5
# 1      Bob   13
# 2  Charlie   22
# 3    David   55
# 4      Eva   49

# %%
df['Status'] = df['Age'].apply(lambda x : "Adult" if x >= 18 else "Child")

# %%
df
# Out:
#       Name  Age Status
# 0    Alice    5  Child
# 1      Bob   13  Child
# 2  Charlie   22  Adult
# 3    David   55  Adult
# 4      Eva   49  Adult

# %%
df['Age']
# Out:
# 0     5
# 1    13
# 2    22
# 3    55
# 4    49
# Name: Age, dtype: int64

# %%
df['Age'].mean()
# Out:
# 28.8

# %%
df['Age'].median()
# Out:
# 22.0

# %%
df['Age'].mode()
# Out:
# 0     5
# 1    13
# 2    22
# 3    49
# 4    55
# Name: Age, dtype: int64

# %%
df['Age'].min()
# Out:
# 5

# %%
df['Age'].max()
# Out:
# 55

# %%
df['Age'].count()
# Out:
# 5

# %%
df['Age'].var()
# Out:
# 489.2

# %%
df['Age'].std()
# Out:
# 22.117866081518805

# %%
df.describe()
# Out:
#              Age
# count   5.000000
# mean   28.800000
# std    22.117866
# min     5.000000
# 25%    13.000000
# 50%    22.000000
# 75%    49.000000
# max    55.000000
